# %% [markdown]
# <a href="https://colab.research.google.com/github/the9kim/Machine-Deep-Learning-Practice/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 0. Limitations of K-NN Regression Model
# - In case where new sample is outside of the trainig dataset

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor

perch_length = np.array([8.4, 13.7, 15.0, 16.2, 17.4, 18.0, 18.7, 19.0, 19.6, 20.0, 21.0,
       21.0, 21.0, 21.3, 22.0, 22.0, 22.0, 22.0, 22.0, 22.5, 22.5, 22.7,
       23.0, 23.5, 24.0, 24.0, 24.6, 25.0, 25.6, 26.5, 27.3, 27.5, 27.5,
       27.5, 28.0, 28.7, 30.0, 32.8, 34.5, 35.0, 36.5, 36.0, 37.0, 37.0,
       39.0, 39.0, 39.0, 40.0, 40.0, 40.0, 40.0, 42.0, 43.0, 43.0, 43.5,
       44.0])

perch_weight = np.array([5.9, 32.0, 40.0, 51.5, 70.0, 100.0, 78.0, 80.0, 85.0, 85.0, 110.0,
       115.0, 125.0, 130.0, 120.0, 120.0, 130.0, 135.0, 110.0, 130.0,
       150.0, 145.0, 150.0, 170.0, 225.0, 145.0, 188.0, 180.0, 197.0,
       218.0, 300.0, 260.0, 265.0, 250.0, 250.0, 300.0, 320.0, 514.0,
       556.0, 840.0, 685.0, 700.0, 700.0, 690.0, 900.0, 650.0, 820.0,
       850.0, 900.0, 1015.0, 820.0, 1100.0, 1000.0, 1100.0, 1000.0,
       1000.0])

train_input, test_input, train_target, test_target = train_test_split(perch_length, perch_weight, random_state=42)

train_input = train_input.reshape((-1, 1))
test_input = test_input.reshape((-1, 1))

knr = KNeighborsRegressor()
knr.n_neighbors = 3
knr.fit(train_input, train_target)

knr.predict([[50]])
# Out:
# array([1033.33333333])

# %%
import matplotlib.pyplot as plt

distances, indexes = knr.kneighbors([[50]])

plt.scatter(train_input, train_target)
plt.scatter(50, 1033, marker='^')
plt.scatter(train_input[indexes], train_target[indexes], marker='D')
plt.show()

print(np.mean(train_target[indexes]))
# Out:
# 1033.3333333333333

# %% [markdown]
# # 1. Linear Regression
# - K-NN Regression is **an Instance-based Learnig** method, whereas Linear regression is a **Model-based Learning** method

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(train_input, train_target)
lr.predict([[50]])
# Out:
# array([1241.83860323])

# %%
# The 'lr.coef_' attribute indicates the slope of the graph
# The 'lr.intercept_' attribute represents the graph intercept

# coef_ and intercept_ attributes are called model parameter

print(lr.coef_, lr.intercept_)
# Out:
# [39.01714496] -709.0186449535477

# %%
plt.scatter(train_input, train_target)
plt.plot([15, 50], [15 * lr.coef_ + lr.intercept_, 50 * lr.coef_ + lr.intercept_])
plt.scatter(50, 1241.8, marker='^')
plt.xlabel('length')
plt.ylabel('weight')
plt.show()

# %%
# The model is underfitted

print(lr.score(train_input, train_target))
print(lr.score(test_input, test_target))
# Out:
# 0.939846333997604
# 0.8247503123313558

# %% [markdown]
# # 2. Polynomial Regression
# - To better represents the data points and increase the complexity of the model

# %%
# Add the Length-squared column to form a Quadratic Equation
train_poly = np.column_stack((train_input ** 2, train_input))
test_poly = np.column_stack((test_input ** 2, test_input))

train_poly.shape
# Out:
# (42, 2)

# %%
lr = LinearRegression()

lr.fit(train_poly, train_target)

print(lr.predict([[50 ** 2, 50]]))
# Out:
# [1573.98423528]

# %%
print(lr.coef_, lr.intercept_)
# Out:
# [  1.01433211 -21.55792498] 116.0502107827827

# %%
point = np.arange(15, 50)

plt.scatter(train_input, train_target)
plt.plot(point, 1.01*point**2 + point * (-21.6) + 116.05)
plt.scatter(50, 1574, marker='^')
plt.xlabel('length')
plt.ylabel('weight')
# Out:
# Text(0, 0.5, 'weight')

# %%
# The model is still underfitted

print(lr.score(train_poly, train_target))
print(lr.score(test_poly, test_target))
# Out:
# 0.9706807451768623
# 0.9775935108325122
